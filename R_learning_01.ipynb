# %%
# **Statistic is the foundation of predictive modeling, machine learning and AI.
# Statistic is a branch of mathematics that deals with the collection, analysis, interpretation, presentation, and organization of data.
# The focus is in quantitive data to extract meaningful information.

# Role of statistic in data science:
#   - Exploratory data analysis(EDA) and data preprocessing
#   - Statistical Estimation and Optimization Techniques
#   - Sampling Techniques
#   - Experimental Desing
#   - Hypothesis Testing
#   - Statistical Modeling



# Descriptive Statistics:
# Descriptive statistics summarize or describe the fundamental characteristics of a dataset, providing concise, objective summaries of samples rather than making predictive inferences about a broader population.
# They are primarily categorized into three groups:
#   1. Measures of Central Tendency
#   2. Measures of Variability (Spread)
#   3. Frequency Distribution & Shape

# Inferential Statistics:
# Inferential statistics is a branch of statistics that uses a random sample to make predictions, test hypotheses, or draw conclusions about a broader population.
# Unlike descriptive statistics (which merely summarize existing data), inferential statistics account for uncertainty and probability to generalize findings
# Core concepts:
#   1. Population vs Sample
#   2. Statistics vs Parameters

# **Statistics is about creating the "tools",
# whereas Applied Statistics is about using those "tools" to address real-world challenges.


# Workflow in R:

#       import data
#             |
#       Perform Data
#        Wrangling
#             |
#           Data
#       Visualization
#             |
#         Statistical____
#         Analysis       \
#      /         |   \    \
#     /          |    \  Machine Learning
# Summarization  |     \
#                |   Modeling
#           Hypothesis
#             Testing
# _______________________________________
#                 |
#                 |
#             Reporting


# Two different ways of data wrangling(cleaning) in R:
#   1. Base R
#   2. Tidyverse(Recommended)

# Different ways of data visualization:
#  - Base R
#  - ggplot2
#  - plotly
#  - leaflet
